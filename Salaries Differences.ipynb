# %% [markdown]
# Salaries Differences
# Write a query that calculates the difference between the highest salaries found in the marketing and engineering departments. Output just the difference in salaries.

# %% [markdown]
# db_employee
# idint64
# first_nameobject
# last_nameobject
# salaryint64
# department_idint64
# db_dept
# idint64
# department

# %%
# Import your libraries
import pandas as pd

# Start writing code
result = db_employee.groupby(['department_id'])['salary'].max().to_frame().reset_index()
id1 = db_dept[db_dept.department == 'engineering'].id.values[0]
id2 = db_dept[db_dept.department == 'marketing'].id.values[0]
result[result.department_id == id2].salary.values[0] - result[result.department_id == id1].salary.values[0]
