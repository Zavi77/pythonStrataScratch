# %% [markdown]
# Find order details made by Jill and Eva.
# Consider the Jill and Eva as first names of customers.
# Output the order date, details and cost along with the first name.
# Order records based on the customer id in ascending order.

# %% [markdown]
# customers
# idint64
# first_nameobject
# last_nameobject
# cityobject
# addressobject
# phone_numberobject
# orders
# id
#
#
# cust_id
# order_datedatetime64[ns]
# order_quantityint64
# order_detailsobject
# order_costint64

# %%
# Import your libraries
import pandas as pd

# Start writing code
customers.head()
df = pd.merge(customers,orders,left_on='id',right_on='cust_id',how='left').sort_values(by = 'cust_id')
df[df.first_name.isin(['Jill', 'Eva'])][['first_name','order_date','order_details','order_cost']]
