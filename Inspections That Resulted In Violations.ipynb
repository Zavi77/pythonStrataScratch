# %% [markdown]
# You're given a dataset of health inspections. Count the number of inspections that resulted in a violation for 'Roxanne Cafe' for each year. If an inspection resulted in a violation, there will be a value in the 'violation_id' column. Output the number of inspections by year in ascending order.

# %% [markdown]
# business_idint64
# business_nameobject
# business_addressobject
# business_cityobject
# business_stateobject
# business_postal_codefloat64
# business_latitudefloat64
# business_longitudefloat64
# business_locationobject
# business_phone_numberfloat64
# inspection_idobject
# inspection_datedatetime64[ns]
# inspection_scorefloat64
# inspection_typeobject
# violation_idobject
# violation_descriptionobject
# risk_categoryobject
# sf_restaurant_health_violations.inspection_date = sf_restaurant_health_violations.inspection_date.apply(lambda x: x.year)

# %%
# Import your libraries
import pandas as pd

# Start writing code
sf_restaurant_health_violations.head()
sf_restaurant_health_violations.inspection_date = sf_restaurant_health_violations.inspection_date.apply(lambda x: x.year)
r1 = sf_restaurant_health_violations[sf_restaurant_health_violations.business_name=='Roxanne Cafe']
r1.groupby('inspection_date').violation_id.count().to_frame().reset_index()
